# %% [markdown]
# <a href="https://colab.research.google.com/github/cmv6316-hash/Python-basic-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello🌍")
# Out:
# Hello🌍

# %%
def greet():
    print("Hello World")

greet()
# Out:
# Hello World

# %%
name = "vinuchethan"
year = "2026"

print("Hello",name)
print(year)
# Out:
# Hello vinuchethan
# 2026
